# %%
import spotipy
import spotipy.util as util

# %%
username = "12143151426"
client_ID = "b0901aadde10452e85c2f4ce2a2c1af7"
client_secret = "d0f1cff199ac47789ca5828cbffd4cc6"
app_redirect_url = "http://localhost/"
#scope = “ ”

util.prompt_for_user_token(username=username, client_id=client_ID, client_secret=client_secret, redirect_uri=app_redirect_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-bce7954d6817> in <module>
#       5 #scope = “ ”
#       6
# ----> 7 util.prompt_for_user_token(username=username, client_id=client_ID, client_secret=client_secret, redirect_uri=app_redirect_url)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/util.py in prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
#      54     # the user to a web page where they can authorize this app)
#      55
# ---> 56     token_info = sp_oauth.get_cached_token()
#      57
#      58     if not token_info:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/oauth2.py in get_cached_token(self)
#     133
#     134                 # if scopes don't match, then bail
# --> 135                 if 'scope' not in token_info or not self._is_scope_subset(self.scope, token_info['scope']):
#     136                     return None
#     137
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spotipy/oauth2.py in _is_scope_subset(self, needle_scope, haystack_scope)
#     154
#     155     def _is_scope_subset(self, needle_scope, haystack_scope):
# --> 156         needle_scope = set(needle_scope.split())
#     157         haystack_scope = set(haystack_scope.split())
#     158
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
import os
username = "12143151426"
os.environ["SPOTIPY_CLIENT_ID"]='b0901aadde10452e85c2f4ce2a2c1af7'
os.environ["SPOTIPY_CLIENT_SECRET"]='d0f1cff199ac47789ca5828cbffd4cc6'
os.environ["SPOTIPY_REDIRECT_URI"]='http://localhost/'

import spotipy
import spotipy.util as util

#I want 5 instrumental tracks by the person I submitted. If we get 30 back, then get the instrumentality of each song...

sp = spotipy.Spotify(auth = token)
results = sp.search(q='madlib', limit = 30)
#print(results['tracks'])
for track in results['tracks']['items']:
    print("{} by {} is available at {}".format(track['name'], track['artists'][0]['name'], track['preview_url']))
# Out:
# Bandana (feat. Assassin) by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/21583ca2259dba4e141e0226d6631d6ecfdd3543?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Get Money by Madlib is available at https://p.scdn.co/mp3-preview/799287aaafb866f6ef75f1014301a05d40aae13b?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Flat Tummy Tea by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/b748a8b0dfebec98d12bea8c7246c22e5cbe8da8?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Thuggin’ by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/a810e991e6b4967058010254fc861f127984bf4e?cid=b0901aadde10452e85c2f4ce2a2c1af7
# High (feat. Danny Brown) by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/9a27da3492d62e192e18d9ec810e946915ad6a31?cid=b0901aadde10452e85c2f4ce2a2c1af7
# ABSOLUTELY by MF DOOM is available at https://p.scdn.co/mp3-preview/03a20d79b87e76b44298ccc373d30d36532a23a8?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Real by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/5f267d471cf746df59b3f2e40eb0185f7034fe26?cid=b0901aadde10452e85c2f4ce2a2c1af7
# The Strip by MED is available at https://p.scdn.co/mp3-preview/677d5cde33a786eaa487e2144133c40dc26c43ef?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Knicks by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/00459cc1107b1a9c7c8dae61a8745c7c4600482a?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Broken (feat. Scarface) by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/8cdaed0ad91b9213c70913aebb86351a0cbac7bc?cid=b0901aadde10452e85c2f4ce2a2c1af7
# Stepping Into Tomorrow by Madlib is available at None
# Lakers (feat. Ab-Soul, Polyester the Saint) by Freddie Gibbs is available at https://p.scdn.co/mp3-preview/756e1a65e04330990873bd32615f3ae6f811966d?cid=b0901aadde10452e85c2f4ce2a2c1af7

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y4inQK6OespitzD6ijMwb'},
#     'href': 'https://api.spotify.com/v1/artists/0Y4inQK6OespitzD6ijMwb',
#     'id': '0Y4inQK6OespitzD6ijMwb',
#     'name': 'Freddie Gibbs',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Y4inQK6OespitzD6ijMwb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'},
#     'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf',
#     'id': '5LhTec3c7dcqBvpLRWbMcf',
#     'name': 'Madlib',
#     'type': 'artist',
#     'uri': 'spotify:artist:5LhTec3c7dcqBvpLRWbMcf'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5Bc89b9FsoOrEZf0HLS812'},
#   'href': 'https://api.spotify.com/v1/albums/5Bc89b9FsoOrEZf0HLS812',
#   'id': '5Bc89b9FsoOrEZf0HLS812',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/fb987f45ec3de66b8d9dfbf8dab8e6649946b77b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/9470121a2b6eb4ac250470dea6cb81738462a017',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/3b95ea834a903da3b019aa024b73878a7555ec97',
#     'width': 64}],
#   'name': 'Bandana (feat. Assassin)',
#   'release_date': '2019-03-05',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5Bc89b9FsoOrEZf0HLS812'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y4inQK6OespitzD6ijMwb'},
#    'href': 'https://api.spotify.com/v1/artists/0Y4inQK6OespitzD6ijMwb',
#    'id': '0Y4inQK6OespitzD6ijMwb',
#    'name': 'Freddie Gibbs',
#    'type': 'artist',
#    'uri': 'spotify:artist:0Y4inQK6OespitzD6ijMwb'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LhTec3c7dcqBvpLRWbMcf'},
#    'href': 'https://api.spotify.com/v1/artists/5LhTec3c7dcqBvpLRWbMcf',
#    'id': '5LhTec3c7dcqBvpLRWbMcf',
#    'name': 'Madlib',
#    'type': 'artist',
#    'uri': 'spotify:artist:5LhTec3c7dcqBvpLRWbMcf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CiLVKp7LJTm0c8jdUmQNy'},
#    'href': 'https://api.spotify.com/v1/artists/0CiLVKp7LJTm0c8jdUmQNy',
#    'id': '0CiLVKp7LJTm0c8jdUmQNy',
#    'name': 'Agent Sasco (Assassin)',
#    'type': 'artist',
#    'uri': 'spotify:artist:0CiLVKp7LJTm0c8jdUmQNy'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 201158,
#  'explicit': True,
#  'external_ids': {'isrc': 'USRC11900364'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7Lj0BNQH9V3zt7AwlWlqrc'},
#  'href': 'https://api.spotify.com/v1/tracks/7Lj0BNQH9V3zt7AwlWlqrc',
#  'id': '7Lj0BNQH9V3zt7AwlWlqrc',
#  'is_local': False,
#  'name': 'Bandana (feat. Assassin)',
#  'popularity': 60,
#  'preview_url': 'https://p.scdn.co/mp3-preview/21583ca2259dba4e141e0226d6631d6ecfdd3543?cid=b0901aadde10452e85c2f4ce2a2c1af7',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:7Lj0BNQH9V3zt7AwlWlqrc'}

# %%
sp.audio_analysis('7Lj0BNQH9V3zt7AwlWlqrc').keys()
# Out:
# dict_keys(['meta', 'track', 'bars', 'beats', 'tatums', 'sections', 'segments'])

# %%
sp.audio_features('7Lj0BNQH9V3zt7AwlWlqrc')
# Out:
# [{'danceability': 0.49,
#   'energy': 0.903,
#   'key': 1,
#   'loudness': -7.657,
#   'mode': 1,
#   'speechiness': 0.304,
#   'acousticness': 0.0443,
#   'instrumentalness': 0.000172,
#   'liveness': 0.139,
#   'valence': 0.631,
#   'tempo': 88.551,
#   'type': 'audio_features',
#   'id': '7Lj0BNQH9V3zt7AwlWlqrc',
#   'uri': 'spotify:track:7Lj0BNQH9V3zt7AwlWlqrc',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Lj0BNQH9V3zt7AwlWlqrc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Lj0BNQH9V3zt7AwlWlqrc',
#   'duration_ms': 201158,
#   'time_signature': 4}]
