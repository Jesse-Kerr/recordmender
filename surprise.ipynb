# %%
import surprise
from pymongo import MongoClient
client = MongoClient()
db = client.whosampled
import numpy as np
import pandas as pd

# %%
from src.turn_db_main_into_utility_matrix import from_mongo_collection_to_utility_matrix

# %%
_, utility_to_artist, _ = from_mongo_collection_to_utility_matrix(db.main_redo)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-faa334d783c4> in <module>
# ----> 1 _, utility_to_artist, _ = from_mongo_collection_to_utility_matrix(db.main_redo)
#
# ~/Documents/recordmender/src/turn_db_main_into_utility_matrix.py in from_mongo_collection_to_utility_matrix(mongo_collection)
#      51
#      52     # make_util(utility_matrix, df)
# ---> 53     utility_to_song = pd.crosstab(df.sampled_artist_song, columns=df.new_song_producer)
#      54     utility_to_artist = pd.crosstab(df.sampled_artist, columns=df.new_song_producer )
#      55
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     519     table = df.pivot_table('__dummy__', index=rownames, columns=colnames,
#     520                            margins=margins, margins_name=margins_name,
# --> 521                            dropna=dropna, **kwargs)
#     522
#     523     # Post-process
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     125
#     126     if fill_value is not None:
# --> 127         table = table.fillna(value=fill_value, downcast='infer')
#     128
#     129     if margins:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    4032                      self).fillna(value=value, method=method, axis=axis,
#    4033                                   inplace=inplace, limit=limit,
# -> 4034                                   downcast=downcast, **kwargs)
#    4035
#    4036     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6121                 new_data = self._data.fillna(value=value, limit=limit,
#    6122                                              inplace=inplace,
# -> 6123                                              downcast=downcast)
#    6124             elif isinstance(value, DataFrame) and self.ndim == 2:
#    6125                 new_data = self.where(self.notna(), value)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in fillna(self, **kwargs)
#     523
#     524     def fillna(self, **kwargs):
# --> 525         return self.apply('fillna', **kwargs)
#     526
#     527     def downcast(self, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast)
#     391             blocks = [b.make_block(values=self._try_coerce_result(b.values))
#     392                       for b in blocks]
# --> 393             return self._maybe_downcast(blocks, downcast)
#     394         except (TypeError, ValueError):
#     395
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _maybe_downcast(self, blocks, downcast)
#     486         if not isinstance(blocks, list):
#     487             blocks = [blocks]
# --> 488         return _extend_blocks([b.downcast(downcast) for b in blocks])
#     489
#     490     def downcast(self, dtypes=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#     486         if not isinstance(blocks, list):
#     487             blocks = [blocks]
# --> 488         return _extend_blocks([b.downcast(downcast) for b in blocks])
#     489
#     490     def downcast(self, dtypes=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in downcast(self, dtypes)
#     528             return v
#     529
# --> 530         return self.split_and_operate(None, f, False)
#     531
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     466             # need a new block
#     467             if m.any():
# --> 468                 nv = f(m, v, i)
#     469             else:
#     470                 nv = v if inplace else v.copy()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in f(m, v, i)
#     525
#     526             if dtype is not None:
# --> 527                 v = maybe_downcast_to_dtype(v, dtype)
#     528             return v
#     529
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_downcast_to_dtype(result, dtype)
#      76     if isinstance(dtype, string_types):
#      77         if dtype == 'infer':
# ---> 78             inferred_type = lib.infer_dtype(ensure_object(result.ravel()),
#      79                                             skipna=False)
#      80             if inferred_type == 'boolean':
#
# KeyboardInterrupt:

# %%
from surprise import Reader
from surprise.model_selection import cross_validate
