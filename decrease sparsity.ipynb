# %%
from pymongo import MongoClient
client = MongoClient()
db = client.whosampled

from src.turn_db_main_into_utility_matrix import from_mongo_collection_to_utility_matrix
_, _, df = from_mongo_collection_to_utility_matrix(db.main_redo)

# %%
# Get list of song_names we will do
df.sampled_artist_song.unique()

# For each of these, want to search it in whosampled. 
#
# Out:
# array(['James Brown - its a new day',
#        'Lyn Collins - we want to parrty, parrty, parrty',
#        'James Brown - get up, get into it, get involved', ...,
#        'Q-Tip - work it out', 'Chaka Khan - fate',
#        'Heatwave - always and forever'], dtype=object)
